# %%
import numpy as np
shots=230000

k = np.random.random([shots,2])

hits=0
for i in k:
    r=pow(i[0:1],2)+pow(i[1:2],2)

    if r<=1:
        hits=hits+1

print(hits)
pi= 4*(hits/shots)

print(pi)
# Out:
# 180669
# 3.1420695652173913
